# %% [markdown]
# <img src="../reports/figures/logotypes/f1.png" alt="F1 logo" width="250"/>
#
# # Formula 1 World Championship (1950 - 2024)

# %% [markdown]
# ### Proposito del Notebook

# %% [markdown]
# Este notebook de la Formula 1 tiene como proposito aprender a ordenar los datos de los datasets y realizar operaciones basicas para aprender a ordenar los datos para analisis de datos

# %%
import sys
import pandas as pd
import numpy as np

# %% [markdown]
# ### Listando los circuitos de carrera de la fromula 1

# %%
df_circuits = pd.read_csv("../data/circuits.csv" , index_col = 0)
df_circuits
# Out:
#             circuitRef                                  name      location  \
# circuitId
# 1          albert_park        Albert Park Grand Prix Circuit     Melbourne
# 2               sepang          Sepang International Circuit  Kuala Lumpur
# 3              bahrain         Bahrain International Circuit        Sakhir
# 4            catalunya        Circuit de Barcelona-Catalunya      Montmeló
# 5             istanbul                         Istanbul Park      Istanbul
# ...                ...                                   ...           ...
# 75            portimao    Autódromo Internacional do Algarve      Portimão
# 76             mugello  Autodromo Internazionale del Mugello       Mugello
# 77              jeddah               Jeddah Corniche Circuit        Jeddah
# 78              losail          Losail International Circuit     Al Daayen
# 79               miami         Miami International Autodrome         Miami
#
#                 country       lat        lng  alt  \
# ...

# %% [markdown]
# ### Contar Circuitos por Paises

# %%
circuits_by_country_count = df_circuits.groupby("country").size()
circuits_by_country_count
# Out:
# country
# Argentina         1
# Australia         2
# Austria           2
# Azerbaijan        1
# Bahrain           1
# Belgium           3
# Brazil            2
# Canada            3
# China             1
# France            7
# Germany           3
# Hungary           1
# India             1
# Italy             4
# Japan             3
# Korea             1
# Malaysia          1
# Mexico            1
# Monaco            1
# Morocco           1
# Netherlands       1
# Portugal          4
# Qatar             1
# Russia            1
# Saudi Arabia      1
# Singapore         1
# South Africa      2
# Spain             6
# Sweden            1
# Switzerland       1
# Turkey            1
# UAE               1
# UK                4
# USA              11
# United States     1
# dtype: int64

# %% [markdown]
# ### Contando el numero de elementos (circuitos) por grupo

# %%
circuits_by_country_elemen = df_circuits.groupby("country").count()
circuits_by_country_element
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[10], line 2
#       1 circuits_by_country_elemen = df_circuits.groupby("country").count()
# ----> 2 circuits_by_country_element
#
# NameError: name 'circuits_by_country_element' is not defined
